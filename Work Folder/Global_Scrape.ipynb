# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

# %%
country_path = "GlobalTemperaturesData/GlobalLandTemperaturesByCountry.csv"
global_path = "GlobalTemperaturesData/GlobalTemperatures.csv"

country_df = pd.read_csv(country_path)
global_df = pd.read_csv(global_path)

# %% [markdown]
# # Country_df

# %%
country_df = country_df[['dt','AverageTemperature','Country']]
country_df = country_df.rename(columns={
    "dt":"date",
    "AverageTemperature":"avgtempcountry",
    "Country":"country"
})

country_df.head()
# Out:
#          date  avgtempcountry country
# 0  1743-11-01           4.384   Åland
# 1  1743-12-01             NaN   Åland
# 2  1744-01-01             NaN   Åland
# 3  1744-02-01             NaN   Åland
# 4  1744-03-01             NaN   Åland

# %% [markdown]
# # North

# %%
USA_df = country_df.loc[country_df['country']=='United States']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = USA_df["date"] >= start_date
before_end_date = USA_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_USA = USA_df.loc[between_two_dates]

filtered_dates_USA['date'] = pd.to_datetime(filtered_dates_USA['date'])

USA_new = filtered_dates_USA.groupby((filtered_dates_USA['date'].dt.year//5)*5).mean()

USA_new = USA_new.rename(columns={
    'avgtempcountry':'avgtempusa'
})

USA_new.head()

#USA_new.plot()
# Out:
# /Users/BenoitViollier/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#       avgtempusa
# date
# 1850    8.474017
# 1855    8.194533
# 1860    8.454550
# 1865    8.371533
# 1870    8.473617

# %%
germany_df = country_df.loc[country_df['country']=='Germany']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = germany_df["date"] >= start_date
before_end_date = germany_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_germany = germany_df.loc[between_two_dates]

filtered_dates_germany['date'] = pd.to_datetime(filtered_dates_germany['date'])

germany_new = filtered_dates_germany.groupby((filtered_dates_germany['date'].dt.year//5)*5).mean()

germany_new = germany_new.rename(columns={
    'avgtempcountry':'avgtempgermany'
})

germany_new.head()

#germany_new.plot()
# Out:
# /Users/BenoitViollier/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#       avgtempgermany
# date
# 1850        7.696783
# 1855        7.766833
# 1860        7.803100
# 1865        8.424700
# 1870        7.821083

# %%
sweden_df = country_df.loc[country_df['country']=='Sweden']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = sweden_df["date"] >= start_date
before_end_date = sweden_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_sweden = sweden_df.loc[between_two_dates]

filtered_dates_sweden['date'] = pd.to_datetime(filtered_dates_sweden['date'])

sweden_new = filtered_dates_sweden.groupby((filtered_dates_sweden['date'].dt.year//5)*5).mean()

sweden_new = sweden_new.rename(columns={
    'avgtempcountry':'avgtempsweden'
})

sweden_new.head()

#sweden_new.plot()
# Out:
# /Users/BenoitViollier/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#       avgtempsweden
# date
# 1850       2.307100
# 1855       2.066467
# 1860       1.941983
# 1865       1.746517
# 1870       2.104850

# %% [markdown]
# # Middle

# %%
venezuela_df = country_df.loc[country_df['country']=='Venezuela']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = venezuela_df["date"] >= start_date
before_end_date = venezuela_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_venezuela = venezuela_df.loc[between_two_dates]

filtered_dates_venezuela['date'] = pd.to_datetime(filtered_dates_venezuela['date'])

venezuela_new = filtered_dates_venezuela.groupby((filtered_dates_venezuela['date'].dt.year//5)*5).mean()

venezuela_new = venezuela_new.rename(columns={
    'avgtempcountry':'avgtempvenezuela'
})

venezuela_new.head()

#venezuela_new.plot()
# Out:
# /Users/BenoitViollier/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#       avgtempvenezuela
# date
# 1850         24.566333
# 1855         24.488200
# 1860         24.453850
# 1865         24.775717
# 1870         24.692800

# %%
congo_df = country_df.loc[country_df['country']=='Congo (Democratic Republic Of The)']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = congo_df["date"] >= start_date
before_end_date = congo_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_congo = congo_df.loc[between_two_dates]

filtered_dates_congo['date'] = pd.to_datetime(filtered_dates_congo['date'])

congo_new = filtered_dates_congo.groupby((filtered_dates_congo['date'].dt.year//5)*5).mean()

congo_new = congo_new.rename(columns={
    'avgtempcountry':'avgtempdemocongo'
})

congo_new.head()

#congo_new.plot()
# Out:
#       avgtempdemocongo
# date
# 1850         23.060727
# 1855         23.232219
# 1860         23.146108
# 1865               NaN
# 1870               NaN

# %%
indonesia_df = country_df.loc[country_df['country']=='Indonesia']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = indonesia_df["date"] >= start_date
before_end_date = indonesia_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_indonesia = indonesia_df.loc[between_two_dates]

filtered_dates_indonesia['date'] = pd.to_datetime(filtered_dates_indonesia['date'])

indonesia_new = filtered_dates_indonesia.groupby((filtered_dates_indonesia['date'].dt.year//5)*5).mean()

indonesia_new = indonesia_new.rename(columns={
    'avgtempcountry':'avgtempindonesia'
})

indonesia_new.head()

#indonesia_new.plot()
# Out:
# /Users/BenoitViollier/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#       avgtempindonesia
# date
# 1850         25.160054
# 1855         25.202250
# 1860               NaN
# 1865         25.311750
# 1870         25.170467

# %% [markdown]
# # South

# %%
argentina_df = country_df.loc[country_df['country']=='Argentina']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = argentina_df["date"] >= start_date
before_end_date = argentina_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_argentina = argentina_df.loc[between_two_dates]

filtered_dates_argentina['date'] = pd.to_datetime(filtered_dates_argentina['date'])

argentina_new = filtered_dates_argentina.groupby((filtered_dates_argentina['date'].dt.year//5)*5).mean()

argentina_new = argentina_new.rename(columns={
    'avgtempcountry':'avgtempargentina'
})

argentina_new.head()

#argentina_new.plot()
# Out:
#       avgtempargentina
# date
# 1855         13.814911
# 1860         13.971783
# 1865         14.362867
# 1870         14.014883
# 1875         14.275983

# %%
new_z_df = country_df.loc[country_df['country']=='New Zealand']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = new_z_df["date"] >= start_date
before_end_date = new_z_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_new_z = new_z_df.loc[between_two_dates]

filtered_dates_new_z['date'] = pd.to_datetime(filtered_dates_new_z['date'])

new_z_new = filtered_dates_new_z.groupby((filtered_dates_new_z['date'].dt.year//5)*5).mean()

new_z_new = new_z_new.rename(columns={
    'avgtempcountry':'avgtempnewzealand'
})

new_z_new.head()

#new_z_new.plot()
# Out:
#       avgtempnewzealand
# date
# 1850           9.306583
# 1855           9.594833
# 1860          10.124267
# 1865          10.280650
# 1870          10.176800

# %%
south_africa_df = country_df.loc[country_df['country']=='South Africa']

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = south_africa_df["date"] >= start_date
before_end_date = south_africa_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates_south_africa = south_africa_df.loc[between_two_dates]

filtered_dates_south_africa['date'] = pd.to_datetime(filtered_dates_south_africa['date'])

south_africa_new = filtered_dates_south_africa.groupby((filtered_dates_south_africa['date'].dt.year//5)*5).mean()

south_africa_new = south_africa_new.rename(columns={
    'avgtempcountry':'avgtempsouthafrica'
})

south_africa_new.head()

#south_africa_new.plot()
# Out:
#       avgtempsouthafrica
# date
# 1855           16.648778
# 1860           16.785776
# 1865           17.052033
# 1870           16.819071
# 1875           16.751800

# %% [markdown]
# # Merge Data

# %%
two_m = USA_new.merge(germany_new, on='date')
three_m = two_m.merge(sweden_new, on='date')
four_m = three_m.merge(venezuela_new, on='date')
five_m = four_m.merge(congo_new, on='date')
six_m = five_m.merge(indonesia_new, on='date')
seven_m = six_m.merge(argentina_new, on='date')
eight_m = seven_m.merge(new_z_new, on='date')
nine_m = eight_m.merge(south_africa_new, on='date')

nine_m
# Out:
#       avgtempusa  avgtempgermany  avgtempsweden  avgtempvenezuela  \
# date
# 1855    8.194533        7.766833       2.066467         24.488200
# 1860    8.454550        7.803100       1.941983         24.453850
# 1865    8.371533        8.424700       1.746517         24.775717
# 1870    8.473617        7.821083       2.104850         24.692800
# 1875    8.469133        7.730267       1.549400         24.985167
# 1880    8.204800        8.034017       2.287517         24.353900
# 1885    8.290950        7.412733       1.951400         24.630133
# 1890    8.338333        7.715650       2.275483         24.389617
# 1895    8.279767        8.002483       2.275533         24.694500
# 1900    8.429683        8.038517       1.858667         24.930533
# 1905    8.466767        7.818433       2.371183         24.649167
# 1910    8.613083        8.455167       2.916817         24.707500
# 1915    8.307417        7.919217       1.748217         24.711550
# ...

# %%
fig = plt.figure(figsize=(12,15))

ax = fig.add_subplot(1,1,1)

nine_m.plot(ax=ax,lw=3,alpha=0.75)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

ax.grid()

# %% [markdown]
# # Global_df

# %%
global_df = global_df.rename(columns={
    "dt":"date",
    "LandAverageTemperature":"avglandtemp",
    "LandAverageTemperatureUncertainty":" ",
    "LandMaxTemperature":"do i care",
    "LandMaxTemperatureUncertainty":" ",
    "LandMinTemperature":"no",
    "LandMinTemperatureUncertainty":" ",
    "LandAndOceanAverageTemperature":"avglandoceantemp",
    "LandAndOceanAverageTemperatureUncertainty":" "
})

global_df = global_df[['date','avglandtemp','avglandoceantemp']]

global_df.head()
# Out:
#          date  avglandtemp  avglandoceantemp
# 0  1750-01-01        3.034               NaN
# 1  1750-02-01        3.083               NaN
# 2  1750-03-01        5.626               NaN
# 3  1750-04-01        8.490               NaN
# 4  1750-05-01       11.573               NaN

# %%
global_df['date'] = pd.to_datetime(global_df['date'])

start_date = "1850-01-01"
end_date = "2016-01-01"

after_start_date = global_df["date"] >= start_date
before_end_date = global_df["date"] <= end_date
between_two_dates = after_start_date & before_end_date
filtered_dates = global_df.loc[between_two_dates]

yearly = filtered_dates.groupby(global_df['date'].dt.year).mean()

yearly.head()
# Out:
#       avglandtemp  avglandoceantemp
# date
# 1850     7.900667         14.867167
# 1851     8.178583         14.991833
# 1852     8.100167         15.006500
# 1853     8.041833         14.955167
# 1854     8.210500         14.991000

# %%
global_new = filtered_dates.groupby((filtered_dates['date'].dt.year//5)*5).mean()

global_new = global_new.rename(columns={
    'avglandtemp':'avgtempGlobal L',
    'avglandoceantemp':'avgtempglobal'
})

global_new = global_new[['avgtempglobal']]

global_new.head()

#df2.to_csv('fiveyr.csv')
# Out:
#       avgtempglobal
# date
# 1850      14.962333
# 1855      14.894017
# 1860      14.851183
# 1865      15.054950
# 1870      15.007167

# %%
plt.plot(global_new['avgtempglobal'])
plt.title("Average Global Temperature (Land and Ocean)")
plt.ylabel("Temperature ˚C")

plt.savefig("graph/globalTemps.pdf")

# %% [markdown]
# # Ultimate Merge

# %%
all_m = nine_m.merge(global_new, on='date')

all_m.head(10)
# Out:
#       avgtempusa  avgtempgermany  avgtempsweden  avgtempvenezuela  \
# date
# 1855    8.194533        7.766833       2.066467         24.488200
# 1860    8.454550        7.803100       1.941983         24.453850
# 1865    8.371533        8.424700       1.746517         24.775717
# 1870    8.473617        7.821083       2.104850         24.692800
# 1875    8.469133        7.730267       1.549400         24.985167
# 1880    8.204800        8.034017       2.287517         24.353900
# 1885    8.290950        7.412733       1.951400         24.630133
# 1890    8.338333        7.715650       2.275483         24.389617
# 1895    8.279767        8.002483       2.275533         24.694500
# 1900    8.429683        8.038517       1.858667         24.930533
#
#       avgtempdemocongo  avgtempindonesia  avgtempargentina  avgtempnewzealand  \
# date
# 1855         23.232219         25.202250         13.814911           9.594833
# ...

# %%
fig = plt.figure(figsize=(12.5,10))

ax = fig.add_subplot(1,1,1)

all_m.plot(ax=ax,lw=3,alpha=0.75)

ax.legend(loc='best', bbox_to_anchor=(1, 0.5))

ax.grid()

plt.savefig('graph/extractedTemps.pdf')

# %% [markdown]
# # Save Data + Figures

# %%
all_m['five_yr_change_global'] = all_m['avgtempglobal'].diff()
all_m['five_yr_change_usa'] = all_m['avgtempusa'].diff()
all_m['five_yr_change_germany'] = all_m['avgtempgermany'].diff()
all_m['five_yr_change_sweden'] = all_m['avgtempsweden'].diff()
all_m['five_yr_change_venezuela'] = all_m['avgtempvenezuela'].diff()
all_m['five_yr_change_democongo'] = all_m['avgtempdemocongo'].diff()
all_m['five_yr_change_indonesia'] = all_m['avgtempindonesia'].diff()
all_m['five_yr_change_argentina'] = all_m['avgtempargentina'].diff()
all_m['five_yr_change_newzealand']= all_m['avgtempnewzealand'].diff()
all_m['five_yr_change_southafrica'] = all_m['avgtempsouthafrica'].diff()

# %%
all_m = all_m.reset_index()

# %%
all_m.head()
# Out:
#    date  avgtempusa  avgtempgermany  avgtempsweden  avgtempvenezuela  \
# 0  1855    8.194533        7.766833       2.066467         24.488200
# 1  1860    8.454550        7.803100       1.941983         24.453850
# 2  1865    8.371533        8.424700       1.746517         24.775717
# 3  1870    8.473617        7.821083       2.104850         24.692800
# 4  1875    8.469133        7.730267       1.549400         24.985167
#
#    avgtempdemocongo  avgtempindonesia  avgtempargentina  avgtempnewzealand  \
# 0         23.232219         25.202250         13.814911           9.594833
# 1         23.146108               NaN         13.971783          10.124267
# 2               NaN         25.311750         14.362867          10.280650
# 3               NaN         25.170467         14.014883          10.176800
# 4         23.362962         25.285633         14.275983          10.177200
#
#    avgtempsouthafrica  ...  five_yr_change_global  five_yr_change_usa  \
# ...

# %%
all_m.to_csv('manipulated_data.csv')

# %%
connection_string = "postgres:postgres@localhost:5432/project_2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['global_df']

# %%
all_m.to_sql(name='global_df', con=engine, if_exists='append', index=False)
